# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lightcurve = np.loadtxt("lc.txt")

# %%
plt.xlabel('time [sec]')
plt.ylabel('brightness [norm]')
plt.plot(lightcurve[:,0], lightcurve[:,1])
plt.plot(lightcurve[:,0], lightcurve[:,2], '--')
plt.show()
