# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lightcurve = np.loadtxt("demo4_lightcurve.txt")

# %%
plt.xlabel('time [sec]')
plt.ylabel('brightness [norm]')
plt.plot(lightcurve[:,0], lightcurve[:,1])
plt.show()
