# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lightcurve = np.loadtxt("lightcurve.txt")

# %%
plt.xlabel('time [sec]')
plt.ylabel('brightness [norm]')
plt.plot(lightcurve[0:1000,0], lightcurve[0:1000,1])
plt.show()
